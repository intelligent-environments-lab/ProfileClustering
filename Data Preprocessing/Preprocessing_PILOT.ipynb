# %%
import numpy as np 
import pandas as pd 
import os 
import h5py 
import csv 
import datetime as dt
import matplotlib.pyplot as plt

# %%
file_loc = 'iel.hdf5'

# %% [markdown]
# <h2><font color = #bf5700>Conversion to pd Data Frame</font></h2>
#
# The data is stored in a dataframe like object with each column (datetime, usage) stored in byte - strings with utf8 encoding. We need to convert data columns from byte-string to datetime and float

# %%
# Convert byte dataframe to one of Datetime + float
def byte_to_obj(build_df):
    df = build_df.copy()
    #Byte to String (decode utf8) to Datetime (parsetime with format YYYY-mm-dd HH:MM:SS)
    df.loc[:,0] = df.apply(lambda x:dt.datetime.strptime(x[0].decode('utf8'),'%Y-%m-%d %H:%M:%S'),axis=1 )
    #Byte to String (decode utf8) to float
    df.loc[:,1] = df.apply(lambda x: float(x[1].decode('utf8')),axis=1)
    return df
#Clean zero values
def clean_zero(build_df):
    df = build_df.copy()
    #Return times and data where usage is positive.
    #Filters zero and negative numbers
    return df[df[1]>0]
#Rencode from Datetime + float to byte:
def reencode(build_df):
    df = build_df.copy()
    df = df.loc[:,(0,1)]
    #Byte to String (decode utf8) to Datetime (parsetime with format YYYY-mm-dd HH:MM:SS)
    df.loc[:,0] = df.apply(lambda x:dt.datetime.strftime(x[0],'%Y-%m-%d %H:%M:%S').encode('utf8'),axis=1 )
    #Byte to String (decode utf8) to float
    df.loc[:,1] = df.apply(lambda x: str(x[1]).encode('utf8'),axis=1)
    return df

# %% [markdown]
# A way to visualize yearly data:

# %%
def plot_hourly(build_df,year,style='-',title='',xlabel = '', ylabel = ''):
    df = build_df.copy()
    df.loc[:,0] = df.apply(lambda x: (x[0]-dt.datetime(year=year,month=1,day=1)).total_seconds()/3600,axis=1)
    plt.plot(df.loc[:,0],df.loc[:,1],style)
    if ylabel == '':
        ylabel = 'Energy Usage (kWH)'
    plt.ylabel(ylabel)
    if xlabel == '':
        xlabel = 'Hours after Jan 1, {} 0:00'.format(year)
    plt.xlabel(xlabel)
    plt.title(title)
    plt.show()

# %% [markdown]
# <h2><font color = #bf5700> Outlier Visualization </font></h2>
#
# Even with the data converted and cleaned, data has extreme outliers, as can be seen below

# %%
with h5py.File(file_loc,'r') as f: 
    df = pd.DataFrame(f['utexas/WEL/2016'][()])
    cleaned = clean_zero(byte_to_obj(df))
    plot_hourly(cleaned,2016,title='WEL 2016 Energy Usage')

# %% [markdown]
# <h2><font color = #bf5700> Log Scale Visualization  </font> </h2>

# %% [markdown]
# Standard outlier detection won't work for several reasons, the main being that the outliers can reach averages as high as 3 million, which significantly skews summary statistics like mean and standard deviation.
#
# A dataset with a lot of these outliers for example, will cause standard mu/sigma or iqr pruning to miss smaller outliers. A log conversion and then a standard pruning was found to work best.

# %%
with h5py.File(file_loc,'r') as f: 
    df = pd.DataFrame(f['utexas/WEL/2016'][()])
    cleaned = clean_zero(byte_to_obj(df))
    cleaned.loc[:,1] = cleaned.apply(lambda x: np.log(x[1]),axis = 1)
    plot_hourly(cleaned,2016,title='WEL 2016 Energy Usage',ylabel ='Log(Energy Usage (kWH))')

# %% [markdown]
# <h2><font color = #bf5700>Log-based mean/sd outlier removal</font></h2>
#
# This function, removes outliers that are within a certain spread. I.e it removes rows whose value at a certain axis (axis) is outside the range of $$(\mu - z\sigma, \mu + z\sigma)$$
# where $z$ is our spread

# %%
def musigma_prune (build_df,axis, spread = 2):
    df = build_df.copy()
    mu = np.mean(df.loc[:,axis])
    sigma = np.std(df.loc[:,axis])
    ub = mu + spread*sigma
    lb = mu - spread*sigma
    return df[(df[axis]<ub) & (df[axis]>lb)]

# %%
def iqr_prune(build_df,axis,spread = 1.5):
    df = build_df.copy()
    q1,q3 = np.percentile(df.loc[:,axis],[25,75])
    ub = q3+spread*(q3-q1)
    lb = q1-spread*(q3-q1)
    return df[(df[axis]<ub) & (df[axis]>lb)]

# %% [markdown]
# <h2><font color = #bf5700>Derivative-based outlier removal</font></h2>

# %% [markdown]
# But soon we will see that this pruning, while effective, is not enough. The reason, is that we are dealing with <b> Time series </b> data. Run the code and look at the plot below. This is the plot of a dormitory building during Jan 2014 - Dec 2014. There are clear drops in the data during winter break, spring break, Thanksgiving break, and the biggest one, summer vacation.

# %%
with h5py.File(file_loc,'r') as f: 
    df = pd.DataFrame(f['utexas/ADH/2014'][()])
    cleaned = clean_zero(byte_to_obj(df))
    cleaned.loc[:,1] = cleaned.apply(lambda x: np.log(x[1]),axis = 1)
    pruned = iqr_prune(cleaned,1,spread = 1.5)
    pruned.loc[:,1] = pruned.apply(lambda x: np.exp(x[1]),axis = 1)
    plot_hourly(pruned,2014,title='Pruned ADH 2014 Energy Usage',ylabel ='Energy Usage (kWH)')

# %% [markdown]
# However, there is a clear outlier in the middle of the winter break period. However, summary statistics <b>cannot</b> detect this as an outlier. The reason is that the value (~240) is <b><i> not </i></b> anomalous for the entire data; it is in line with school-time energy usage. But it is anomalous given its surroundings. So we need to calculate the derivative to remove any outliers

# %%
#Adds a derivative column to a df
def gen_deriv(build_df,axis):
    df = build_df.copy()
    df.sort_values(by=0,inplace=True)
    derivatives = [0]
    temp = np.nan 
    i = 0 
    for m in df.loc[:,axis]:
        i = i+1
        if temp is np.nan:
            temp = m
        else:
            derivatives.append(m-temp)
            temp = m
    df.loc[:,'D'] = derivatives
    return df

# %%
with h5py.File(file_loc,'r') as f: 
    df = pd.DataFrame(f['utexas/ADH/2014'][()])
    cleaned = clean_zero(byte_to_obj(df))
    cleaned.loc[:,1] = cleaned.apply(lambda x: np.log(x[1]),axis = 1)
    pruned = iqr_prune(cleaned,1,spread = 2)
    print(gen_deriv(pruned,1).head())
# Out:
#                     0         1         D
# 0 2014-01-01 00:00:00  4.892227  0.000000
# 1 2014-01-01 01:00:00  4.892227  0.000000
# 2 2014-01-01 02:00:00  4.903421  0.011194
# 3 2014-01-01 03:00:00  4.901564 -0.001857
# 4 2014-01-01 04:00:00  4.894101 -0.007463

# %% [markdown]
# Then a second round of outlier removal can commence, and the results are visibly better

# %%
with h5py.File(file_loc,'r') as f: 
    df = pd.DataFrame(f['utexas/ADH/2014'][()])
    cleaned = clean_zero(byte_to_obj(df))
    cleaned.loc[:,1] = cleaned.apply(lambda x: np.log(x[1]),axis = 1)
    pruned = iqr_prune(cleaned,1,spread = 1.5)
    pruned = gen_deriv(pruned,1)
    pruned = iqr_prune(pruned,'D',spread = 1.5)
    print(1-len(pruned)/len(cleaned))
    pruned.loc[:,1] = pruned.apply(lambda x: np.exp(x[1]),axis = 1)
    plot_hourly(pruned,2014,title='Pruned ADH 2014 Energy Usage',ylabel ='Energy Usage (kWH)')
# Out:
# 0.07397483690587137

# %% [markdown]
# <h2><font color = #bf5700>Single preprocessing method</font></h2>
# We can summarize all the outlier removal steps into one method, below.

# %%
def outlier_prune(build_df,method='p'):
    raw = build_df.copy()
    in_len = len(raw)
    if(in_len ==0):
        if(method == 'p'):
            print('Empty dataset')
            return 0
        else:
            return (0,0)
    df = clean_zero(byte_to_obj(raw))
    if(len(df) ==0):
        if(method == 'p'):
            print('Empty dataset')
            return 0
        else:
            return (0,0)
    df.loc[:,1] = df.apply(lambda x: np.log(x[1]),axis =1) 
    df = gen_deriv(df,axis = 1)
    df = iqr_prune(df,axis=1,spread=1.5)
    if(len(df)==0):
        if(method == 'p'):
            print('Empty dataset')
            return 0
        else:
            return (0,0)
    df = iqr_prune(df,axis='D',spread=1.5)
    if(len(df)==0):
        if(method == 'p'):
            print('Empty dataset')
            return 0
        else:
            return (0,0)
    df.loc[:,1] = df.apply(lambda x: np.exp(x[1]),axis=1)
    if(method =='p' or method =='P'):
        print('{}% of outliers pruned'.format((1-len(df)/in_len)*100))
        return df
    else: 
        return (df,(1-len(df)/in_len)*100)
def plot_utexas(building,year,style='-'):
    with h5py.File(file_loc,'r') as f: 
        try:
            data= pd.DataFrame(f['utexas/{}/{}'.format(building,year)][()])
            cleaned = clean_zero(byte_to_obj(data))
            plot_hourly(outlier_prune(cleaned),year,style)
        except:
            print('{} data for building {} not found'.format(year,building))

# %%
import matplotlib.pyplot as plt
def daily_profile(dset,building, year, prune = True):
    with h5py.File('cleaned.hdf5','r') as f:
        df = pd.DataFrame(f['{}/{}/{}'.format(dset,building,year)][()])
        if prune:
            df = outlier_prune(df)
        else:
            df = clean_zero(byte_to_obj(df))
        hour_avs= []
        for h in range(24):
            hour_data = df[df.apply(lambda x: x[0].hour==h,axis=1)][1]
            hour_avs.append(sum(hour_data)/len(hour_data))
        return hour_avs

# %%
def yearly_profile(building,year, prune = True):
    with h5py.File(file_loc,'r') as f:
        df = pd.DataFrame(f['utexas/{}/{}'.format(building,year)][()])
        if prune:
            df = outlier_prune(df)
        else:
            df = clean_zero(byte_to_obj(df))
        hour_avs= []
        for h in range(24):
            hour_data = df[df.apply(lambda x: x[0].hour==h,axis=1)][1]
            hour_avs.append(sum(hour_data)/len(hour_data))
        return hour_avs

# %%
with h5py.File(file_loc,'r') as f:
    df = pd.DataFrame(f['ireland/1049/2010'][()])
    df = clean_zero(byte_to_obj(df))
    plot_hourly(df,2010)

# %%
with h5py.File(file_loc,'r') as f:
    df = pd.DataFrame(f['ireland/1049/2010'][()])
    df =outlier_prune(df)
    plot_hourly(df,2010)
# Out:
# 5.503539620918019% of outliers pruned

# %%
buildings = []
with h5py.File('cleaned.hdf5','r') as f: 
    for b in f['utexas'].keys():
        building = f['utexas/{}'.format(b)]
        if '2010' in building: 
            buildings.append(b)

# %%
profs = []
nme = []
for i in buildings:
    arr = daily_profile('utexas',i,2010, prune = False)
    barr = np.array(arr)-np.mean(arr)
    profs.append(barr.reshape((-1,1)))
    nme.append(np.array(arr).reshape((-1,1)))
# Out:
# ADH
# AHG
# AND
# ARC
# ATT
# BAT
# BEL
# BIO
# BMA
# CPE
# ERC
# GRE
# GSB
# KIN
# NMS
# PCL
# WEL

# %%
for i in range(len(profs)):
    profs[i] = profs[i]/np.std(profs[i])

# %%
plt.xlabel('Hour of the Day')
plt.ylabel('z-score of Energy consumption (kW)')
plt.title('utexas/2010 Daily Profile')
i=0
for prof in profs:
    plt.plot(np.arange(24),prof,label=buildings[i])
    i=i+1
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
def clean_and_copy(dset):
    with h5py.File('iel.hdf5') as f:
        if(dset not in f):
            print('Dataset not found')
        else:
            with h5py.File('cleaned.hdf5') as cl:
                if dset not in cl: 
                    cl_dset = cl.create_group(dset)
                    num = len(f[dset].keys())
                    i=0
                    for building in f[dset].keys():
                        i = i+1
                        print('Now Copying Building #{}/{}.........{}'.format(i,num,building))
                        b = f['{}/{}'.format(dset,building)]
                        cl_b = cl_dset.create_group(building)
                        for year in b.keys():
                            print('..........Year:{}'.format(year))
                            df = pd.DataFrame(b[year][()])
                            vals = outlier_prune(df, method='r')
                            if(vals[0] is 0):
                                print('Empty dataset found')
                            else:
                                cl_b[year] = reencode(vals[0]).as_matrix().astype(np.string_)
                                cl_b[year].attrs['outlier'] = vals[1]
                                b[year].attrs['outlier']=vals[1]
                                for m in b.attrs:
                                    cl_b.attrs[m]=b.attrs[m]

# %%
clean_and_copy('utexas')
# Out:
# Now Copying Building #1/112.........ADH
# ..........Year:2009
# ..........Year:2010
# ..........Year:2011
# ..........Year:2012
# ..........Year:2013
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #2/112.........AHG
# ..........Year:2010
# ..........Year:2011
# ..........Year:2012
# ..........Year:2013
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #3/112.........ANB
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #4/112.........AND
# ..........Year:2010
# ..........Year:2011
# ..........Year:2012
# ..........Year:2013
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #5/112.........ARC
# ..........Year:2009
# ..........Year:2010
# ..........Year:2011
# ..........Year:2012
# ..........Year:2013
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #6/112.........ART
# ..........Year:2011
# ..........Year:2012
# ..........Year:2013
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #7/112.........ATT
# ..........Year:2010
# ..........Year:2011
# ..........Year:2012
# ..........Year:2013
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #8/112.........BAT
# ..........Year:2010
# ..........Year:2011
# ..........Year:2012
# ..........Year:2013
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #9/112.........BEL
# ..........Year:2009
# ..........Year:2010
# ..........Year:2011
# ..........Year:2012
# ..........Year:2013
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #10/112.........BEN
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #11/112.........BIO
# ..........Year:2009
# ..........Year:2010
# ..........Year:2011
# ..........Year:2012
# ..........Year:2013
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #12/112.........BLD
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #13/112.........BMA
# ..........Year:2009
# ..........Year:2010
# ..........Year:2011
# ..........Year:2012
# ..........Year:2013
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #14/112.........BMC
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #15/112.........BME
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #16/112.........BRB
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #17/112.........BRD
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #18/112.........BTL
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #19/112.........BUR
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #20/112.........CAL
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #21/112.........CBA
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #22/112.........CDL
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #23/112.........CLA
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #24/112.........CMA
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #25/112.........CMB
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #26/112.........COM
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #27/112.........CPE
# ..........Year:2009
# ..........Year:2010
# ..........Year:2011
# ..........Year:2012
# ..........Year:2013
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #28/112.........CRB
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #29/112.........CRD
# ..........Year:2012
# ..........Year:2013
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #30/112.........CRH
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #31/112.........DCP
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #32/112.........DFA
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #33/112.........DFF
# ..........Year:2016
# ..........Year:2017
# Now Copying Building #34/112.........EAS
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017
# Now Copying Building
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# ..........Year:2017

# %%
clean_and_copy('genome')
# Out:
# Now Copying Building #1/507.........Office_Abbey
# ..........Year:2015
# Now Copying Building #2/507.........Office_Abigail
# ..........Year:2015
# Now Copying Building #3/507.........Office_Al
# ..........Year:2015
# Now Copying Building #4/507.........Office_Alannah
# ..........Year:2015
# Now Copying Building #5/507.........Office_Aliyah
# ..........Year:2015
# Now Copying Building #6/507.........Office_Allyson
# ..........Year:2015
# Now Copying Building #7/507.........Office_Alyson
# ..........Year:2015
# Now Copying Building #8/507.........Office_Amelia
# ..........Year:2015
# Now Copying Building #9/507.........Office_Amelie
# ..........Year:2015
# Now Copying Building #10/507.........Office_Anastasia
# ..........Year:2015
# Now Copying Building #11/507.........Office_Andrea
# ..........Year:2015
# Now Copying Building #12/507.........Office_Angelica
# ..........Year:2015
# Now Copying Building #13/507.........Office_Angelina
# ..........Year:2015
# Now Copying Building #14/507.........Office_Angelo
# ..........Year:2015
# Now Copying Building #15/507.........Office_Annika
# ..........Year:2015
# Now Copying Building #16/507.........Office_Ashanti
# ..........Year:2015
# Now Copying Building #17/507.........Office_Asher
# ..........Year:2015
# Now Copying Building #18/507.........Office_Aubrey
# ..........Year:2015
# Now Copying Building #19/507.........Office_Autumn
# ..........Year:2015
# Now Copying Building #20/507.........Office_Ava
# ..........Year:2015
# Now Copying Building #21/507.........Office_Ayden
# ..........Year:2015
# Now Copying Building #22/507.........Office_Ayesha
# ..........Year:2015
# Now Copying Building #23/507.........Office_Benjamin
# ..........Year:2012
# Now Copying Building #24/507.........Office_Benthe
# ..........Year:2012
# Now Copying Building #25/507.........Office_Bianca
# ..........Year:2012
# Now Copying Building #26/507.........Office_Bobbi
# ..........Year:2012
# Now Copying Building #27/507.........Office_Brian
# ..........Year:2012
# Now Copying Building #28/507.........Office_Bryon
# ..........Year:2012
# Now Copying Building #29/507.........Office_Caleb
# ..........Year:2015
# Now Copying Building #30/507.........Office_Cameron
# ..........Year:2015
# Now Copying Building #31/507.........Office_Carissa
# ..........Year:2015
# Now Copying Building #32/507.........Office_Carolina
# ..........Year:2015
# Now Copying Building #33/507.........Office_Catherine
# ..........Year:2015
# Now Copying Building #34/507.........Office_Cecelia
# ..........Year:2015
# Now Copying Building #35/507.........Office_Charles
# ..........Year:2015
# Now Copying Building #36/507.........Office_Clarissa
# ..........Year:2015
# Now Copying Building #37/507.........Office_Clifton
# ..........Year:2015
# Now Copying Building #38/507.........Office_Clinton
# ..........Year:2015
# Now Copying Building #39/507.........Office_Cody
# ..........Year:2015
# Now Copying Building #40/507.........Office_Colby
# ..........Year:2015
# Now Copying Building #41/507.........Office_Conrad
# ..........Year:2015
# Now Copying Building #42/507.........Office_Cora
# ..........Year:2015
# Now Copying Building #43/507.........Office_Corbin
# ..........Year:2015
# Now Copying Building #44/507.........Office_Cristina
# ..........Year:2015
# Now Copying Building #45/507.........Office_Curt
# ..........Year:2015
# Now Copying Building #46/507.........Office_Dawn
# ..........Year:2010
# Now Copying Building #47/507.........Office_Dorian
# ..........Year:2010
# Now Copying Building #48/507.........Office_Eddie
# ..........Year:2012
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #133/507.........Office_Paige
# ..........Year:2015
# Now Copying Building #134/507.........Office_Pam
# ..........Year:2015
# Now Copying Building #135/507.........Office_Pamela
# ..........Year:2015
# Now Copying Building #136/507.........Office_Pasquale
# ..........Year:2015
# Now Copying Building #137/507.........Office_Pat
# ..........Year:2015
# Now Copying Building #138/507.........Office_Patricia
# ..........Year:2015
# Now Copying Building #139/507.........Office_Paula
# ..........Year:2015
# Now Copying Building #140/507.........Office_Paulette
# ..........Year:2015
# Now Copying Building #141/507.........Office_Paulina
# ..........Year:2015
# Now Copying Building #142/507.........Office_Pauline
# ..........Year:2015
# Now Copying Building #143/507.........Office_Penny
# ..........Year:2015
# Now Copying Building #144/507.........Office_Perla
# ..........Year:2015
# Now Copying Building #145/507.........Office_Phebian
# ..........Year:2015
# Now Copying Building #146/507.........Office_Precious
# ..........Year:2015
# Now Copying Building #147/507.........Office_Scottie
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #148/507.........Office_Shari
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #149/507.........Office_Shawnette
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #150/507.........Office_Shelly
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #151/507.........Office_Sinead
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #152/507.........Office_Skyler
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #153/507.........Office_Stella
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #154/507.........Office_Terrell
# ..........Year:2013
# Now Copying Building #155/507.........Office_Tod
# ..........Year:2013
# Now Copying Building #156/507.........Office_Travis
# ..........Year:2013
# Now Copying Building #157/507.........PrimClass_Angel
# ..........Year:2015
# Now Copying Building #158/507.........PrimClass_Angela
# ..........Year:2015
# Now Copying Building #159/507.........PrimClass_Ebony
# ..........Year:2012
# Now Copying Building #160/507.........PrimClass_Edmund
# ..........Year:2012
# Now Copying Building #161/507.........PrimClass_Edwin
# ..........Year:2012
# Now Copying Building #162/507.........PrimClass_Eleanor
# ..........Year:2012
# Now Copying Building #163/507.........PrimClass_Eli
# ..........Year:2012
# Now Copying Building #164/507.........PrimClass_Elijah
# ..........Year:2012
# Now Copying Building #165/507.........PrimClass_Elisabeth
# ..........Year:2012
# Now Copying Building #166/507.........PrimClass_Ellen
# ..........Year:2012
# Now Copying Building #167/507.........PrimClass_Elliott
# ..........Year:2012
# Now Copying Building #168/507.........PrimClass_Elmer
# ..........Year:2012
# Now Copying Building #169/507.........PrimClass_Emanuela
# ..........Year:2012
# Now Copying Building #170/507.........PrimClass_Emilio
# ..........Year:2012
# Now Copying Building #171/507.........PrimClass_Emily
# ..........Year:2012
# Now Copying Building #172/507.........PrimClass_Eoghan
# ..........Year:2012
# Now Copying Building #173/507.........PrimClass_Ernest
# ..........Year:2012
# Now Copying Building #174/507.........PrimClass_Ernesto
# ..........Year:2012
# Now Copying Building #175/507.........PrimClass_Ervin
# ..........Year:2012
# Now Copying Building #176/507.........PrimClass_Esmeralda
# ..........Year:2012
# Now Copying Building #177/507.........PrimClass_Ethan
# ..........Year:2012
# Now Copying Building #178/507.........PrimClass_Ethel
# ..........Year:2012
# Now Copying Building #179/507.........PrimClass_Eva
# ..........Year:2012
# Now Copying Building #180/507.........PrimClass_Everett
# ..........Year:2012
# Now Copying Building #181/507.........PrimClass_Evie
# ..........Year:2012
# Now Copying Building #182/507.........PrimClass_Ezekiel
# ..........Year:2012
# Now Copying Building #183/507.........PrimClass_Ezra
# ..........Year:2012
# Now Copying Building #184/507.........PrimClass_Jacob
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #185/507.........PrimClass_Jacqueline
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #186/507.........PrimClass_Jacquelyn
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #187/507.........PrimClass_Jaden
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #188/507.........PrimClass_Jaiden
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #189/507.........PrimClass_Jake
# ..........Year:2014
# ..........Year:2015
# Now Copying Building
# Now Copying Building #266/507.........UnivClass_Alec
# ..........Year:2015
# Now Copying Building #267/507.........UnivClass_Alejandra
# ..........Year:2015
# Now Copying Building #268/507.........UnivClass_Alexander
# ..........Year:2015
# Now Copying Building #269/507.........UnivClass_Alexandra
# ..........Year:2015
# Now Copying Building #270/507.........UnivClass_Alexandria
# ..........Year:2015
# Now Copying Building #271/507.........UnivClass_Alexus
# ..........Year:2015
# Now Copying Building #272/507.........UnivClass_Alfredo
# ..........Year:2015
# Now Copying Building #273/507.........UnivClass_Alicia
# ..........Year:2015
# Now Copying Building #274/507.........UnivClass_Allen
# ..........Year:2015
# Now Copying Building #275/507.........UnivClass_Alvin
# ..........Year:2015
# Now Copying Building #276/507.........UnivClass_Amari
# ..........Year:2015
# Now Copying Building #277/507.........UnivClass_Amya
# ..........Year:2015
# Now Copying Building #278/507.........UnivClass_Anamaria
# ..........Year:2015
# Now Copying Building #279/507.........UnivClass_Andy
# ..........Year:2015
# Now Copying Building #280/507.........UnivClass_Anika
# ..........Year:2015
# Now Copying Building #281/507.........UnivClass_Annabella
# ..........Year:2015
# Now Copying Building #282/507.........UnivClass_Anne
# ..........Year:2015
# Now Copying Building #283/507.........UnivClass_Annmarie
# ..........Year:2015
# Now Copying Building #284/507.........UnivClass_Antoinette
# ..........Year:2015
# Now Copying Building #285/507.........UnivClass_Anya
# ..........Year:2015
# Now Copying Building #286/507.........UnivClass_Aoibhe
# ..........Year:2015
# Now Copying Building #287/507.........UnivClass_Archie
# ..........Year:2015
# Now Copying Building #288/507.........UnivClass_Ariana
# ..........Year:2015
# Now Copying Building #289/507.........UnivClass_Armando
# ..........Year:2015
# Now Copying Building #290/507.........UnivClass_Axel
# ..........Year:2015
# Now Copying Building #291/507.........UnivClass_Ayanna
# ..........Year:2015
# Now Copying Building #292/507.........UnivClass_Beatrice
# ..........Year:2012
# Now Copying Building #293/507.........UnivClass_Bob
# ..........Year:2012
# Now Copying Building #294/507.........UnivClass_Boyd
# ..........Year:2012
# Now Copying Building #295/507.........UnivClass_Brett
# ..........Year:2012
# Now Copying Building #296/507.........UnivClass_Caitlyn
# ..........Year:2015
# Now Copying Building #297/507.........UnivClass_Calvin
# ..........Year:2015
# Now Copying Building #298/507.........UnivClass_Camden
# ..........Year:2015
# Now Copying Building #299/507.........UnivClass_Candy
# ..........Year:2015
# Now Copying Building #300/507.........UnivClass_Caoimhe
# ..........Year:2015
# Now Copying Building #301/507.........UnivClass_Carl
# ..........Year:2015
# Now Copying Building #302/507.........UnivClass_Carolyn
# ..........Year:2015
# Now Copying Building #303/507.........UnivClass_Cathleen
# ..........Year:2015
# Now Copying Building #304/507.........UnivClass_Celia
# ..........Year:2015
# Now Copying Building #305/507.........UnivClass_Chandler
# ..........Year:2015
# Now Copying Building #306/507.........UnivClass_Charlie
# ..........Year:2015
# Now Copying Building #307/507.........UnivClass_Christian
# ..........Year:2015
# Now Copying Building #308/507.........UnivClass_Ciara
# ..........Year:2015
# Now Copying Building #309/507.........UnivClass_Clay
# ..........Year:2015
# Now Copying Building #310/507.........UnivClass_Clifford
# ..........Year:2015
# Now Copying Building #311/507.........UnivClass_Colette
# ..........Year:2015
# Now Copying Building #312/507.........UnivClass_Conner
# ..........Year:2015
# Now Copying Building #313/507.........UnivClass_Conor
# ..........Year:2015
# Now Copying Building #314/507.........UnivClass_Craig
# ..........Year:2015
# Now Copying Building #315/507.........UnivClass_Jadon
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #316/507.........UnivClass_Maddison
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #317/507.........UnivClass_Nash
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #318/507.........UnivClass_Nathaniel
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #319/507.........UnivClass_Nayeli
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #320/507.........UnivClass_Nelly
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #321/507.........UnivClass_Nicholas
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #322/507.........UnivClass_Nickolas
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #323/507.........UnivClass_Nishka
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #324/507.........UnivClass_Noreen
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #325/507.........UnivClass_Pandora
# ..........Year:2015
# Now Copying Building #326/507.........UnivClass_Pete
# ..........Year:2015
# Now Copying Building #327/507.........UnivClass_Peter
# ..........Year:2015
# Now Copying Building #328/507.........UnivClass_Philip
# ..........Year:2015
# Now Copying Building #329/507.........UnivClass_Phyllis
# ..........Year:2015
# Now Copying Building #330/507.........UnivClass_Sam
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #331/507.........UnivClass_Seb
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #332/507.........UnivClass_Serenity
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #333/507.........UnivClass_Shawna
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #334/507.........UnivClass_Sheila
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #335/507.........UnivClass_Stephanie
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #336/507.........UnivClass_Stephen
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #337/507.........UnivClass_Stuart
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #338/507.........UnivClass_Sylvia
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #339/507.........UnivClass_Tammy
# ..........Year:2013
# Now Copying Building #340/507.........UnivClass_Tamra
# ..........Year:2013
# Now Copying Building #341/507.........UnivClass_Teri
# ..........Year:2013
# Now Copying Building #342/507.........UnivClass_Therese
# ..........Year:2013
# Now Copying Building #343/507.........UnivDorm_Adan
# ..........Year:2015
# Now Copying Building #344/507.........UnivDorm_Adriana
# ..........Year:2015
# Now Copying Building #345/507.........UnivDorm_Ahmad
# ..........Year:2015
# Now Copying Building #346/507.........UnivDorm_Alex
# ..........Year:2015
# Now Copying Building #347/507.........UnivDorm_Alka
# ..........Year:2015
# Now Copying Building #348/507.........UnivDorm_Alonzo
# ..........Year:2015
# Now Copying Building #349/507.........UnivDorm_Alphonso
# ..........Year:2015
# Now Copying Building #350/507.........UnivDorm_Alyshialynn
# ..........Year:2015
# Now Copying Building #351/507.........UnivDorm_Alyssa
# ..........Year:2015
# Now Copying Building #352/507.........UnivDorm_Antonio
# ..........Year:2015
# Now Copying Building #353/507.........UnivDorm_April
# ..........Year:2015
# Now Copying Building #354/507.........UnivDorm_Ashleigh
# ..........Year:2015
# Now Copying Building #355/507.........UnivDorm_Avery
# ..........Year:2015
# Now Copying Building #356/507.........UnivDorm_Camila
# ..........Year:2015
# Now Copying Building #357/507.........UnivDorm_Candace
# ..........Year:2015
# Now Copying Building #358/507.........UnivDorm_Cara
# ..........Year:2015
# Now Copying Building #359/507.........UnivDorm_Carey
# ..........Year:2015
# Now Copying Building #360/507.........UnivDorm_Carla
# ..........Year:2015
# Now Copying Building #361/507.........UnivDorm_Carter
# ..........Year:2015
# Now Copying Building #362/507.........UnivDorm_Casey
# ..........Year:2015
# Now Copying Building #363/507.........UnivDorm_Cathal
# ..........Year:2015
# Now Copying Building #364/507.........UnivDorm_Cathalina
# ..........Year:2015
# Now Copying Building #365/507.........UnivDorm_Cecilia
# ..........Year:2015
# Now Copying Building #366/507.........UnivDorm_Celeste
# ..........Year:2015
# Now Copying Building #367/507.........UnivDorm_Chelsey
# ..........Year:2015
# Now Copying Building #368/507.........UnivDorm_Cheri
# ..........Year:2015
# Now Copying Building #369/507.........UnivDorm_Chester
# ..........Year:2015
# Now Copying Building #370/507.........UnivDorm_Cheyenne
# ..........Year:2015
# Now Copying Building #371/507.........UnivDorm_Christi
# ..........Year:2015
# Now Copying Building #372/507.........UnivDorm_Christopher
# ..........Year:2015
# Now Copying Building #373/507.........UnivDorm_Cian
# ..........Year:2015
# Now Copying Building #374/507.........UnivDorm_Ciaran
# ..........Year:2015
# Now Copying Building #375/507.........UnivDorm_Claudia
# ..........Year:2015
# Now Copying Building #376/507.........UnivDorm_Clayton
# ..........Year:2015
# Now Copying Building #377/507.........UnivDorm_Colton
# ..........Year:2015
# Now Copying Building #378/507.........UnivDorm_Constance
# ..........Year:2015
# Now Copying Building #379/507.........UnivDorm_Cooper
# ..........Year:2015
# Now Copying Building #380/507.........UnivDorm_Corey
# ..........Year:2015
# Now Copying Building #381/507.........UnivDorm_Cornelius
# ..........Year:2015
# Now Copying Building #382/507.........UnivDorm_Curtis
# ..........Year:2015
# Now Copying Building #383/507.........UnivDorm_Jeannette
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #384/507.........UnivDorm_Laura
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #385/507.........UnivDorm_Lawrence
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #386/507.........UnivDorm_Leann
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #387/507.........UnivDorm_Leonard
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #388/507.........UnivDorm_Leslie
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #389/507.........UnivDorm_Leticia
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #390/507.........UnivDorm_Lorraine
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #391/507.........UnivDorm_Lysander
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #392/507.........UnivDorm_Malachi
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #393/507.........UnivDorm_Malcolm
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #394/507.........UnivDorm_Marlene
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #395/507.........UnivDorm_Marquis
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #396/507.........UnivDorm_Mathew
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #397/507.........UnivDorm_Mauricio
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #398/507.........UnivDorm_Mckenzie
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #399/507.........UnivDorm_Mitch
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #400/507.........UnivDorm_Paola
# ..........Year:2015
# Now Copying Building #401/507.........UnivDorm_Patrice
# ..........Year:2015
# Now Copying Building #402/507.........UnivDorm_Patti
# ..........Year:2015
# Now Copying Building #403/507.........UnivDorm_Patty
# ..........Year:2015
# Now Copying Building #404/507.........UnivDorm_Payton
# ..........Year:2015
# Now Copying Building #405/507.........UnivDorm_Pedro
# ..........Year:2015
# Now Copying Building #406/507.........UnivDorm_Petar
# ..........Year:2015
# Now Copying Building #407/507.........UnivDorm_Phillip
# ..........Year:2015
# Now Copying Building #408/507.........UnivDorm_Phoebe
# ..........Year:2015
# Now Copying Building #409/507.........UnivDorm_Piper
# ..........Year:2015
# Now Copying Building #410/507.........UnivDorm_Poppy
# ..........Year:2015
# Now Copying Building #411/507.........UnivDorm_Prince
# ..........Year:2015
# Now Copying Building #412/507.........UnivDorm_Una
# ..........Year:2012
# ..........Year:2013
# Now Copying Building #413/507.........UnivLab_Adrian
# ..........Year:2015
# Now Copying Building #414/507.........UnivLab_Aine
# ..........Year:2015
# Now Copying Building #415/507.........UnivLab_Alaina
# ..........Year:2015
# Now Copying Building #416/507.........UnivLab_Albert
# ..........Year:2015
# Now Copying Building #417/507.........UnivLab_Alberto
# ..........Year:2015
# Now Copying Building #418/507.........UnivLab_Alexis
# ..........Year:2015
# Now Copying Building #419/507.........UnivLab_Alfonso
# ..........Year:2015
# Now Copying Building #420/507.........UnivLab_Ali
# ..........Year:2015
# Now Copying Building #421/507.........UnivLab_Alina
# ..........Year:2015
# Now Copying Building #422/507.........UnivLab_Alisa
# ..........Year:2015
# Now Copying Building #423/507.........UnivLab_Allan
# ..........Year:2015
# Now Copying Building #424/507.........UnivLab_Allison
# ..........Year:2015
# Now Copying Building #425/507.........UnivLab_Amaya
# ..........Year:2015
# Now Copying Building #426/507.........UnivLab_Amy
# ..........Year:2015
# Now Copying Building #427/507.........UnivLab_Ana
# ..........Year:2015
# Now Copying Building #428/507.........UnivLab_Andre
# ..........Year:2015
# Now Copying Building #429/507.........UnivLab_Angie
# ..........Year:2015
# Now Copying Building #430/507.........UnivLab_Anita
# ..........Year:2015
# Now Copying Building #431/507.........UnivLab_Aniya
# ..........Year:2015
# Now Copying Building #432/507.........UnivLab_Annabelle
# ..........Year:2015
# Now Copying Building #433/507.........UnivLab_Annette
# ..........Year:2015
# Now Copying Building #434/507.........UnivLab_Aoife
# ..........Year:2015
# Now Copying Building #435/507.........UnivLab_Arianna
# ..........Year:2015
# Now Copying Building #436/507.........UnivLab_Ariel
# ..........Year:2015
# Now Copying Building #437/507.........UnivLab_Ashlee
# ..........Year:2015
# Now Copying Building #438/507.........UnivLab_Ashlynn
# ..........Year:2015
# Now Copying Building #439/507.........UnivLab_Ashton
# ..........Year:2015
# Now Copying Building #440/507.........UnivLab_Audra
# ..........Year:2015
# Now Copying Building #441/507.........UnivLab_Aurora
# ..........Year:2015
# Now Copying Building #442/507.........UnivLab_Bert
# ..........Year:2012
# Now Copying Building #443/507.........UnivLab_Beth
# ..........Year:2012
# Now Copying Building #444/507.........UnivLab_Bethany
# ..........Year:2012
# Now Copying Building #445/507.........UnivLab_Brad
# ..........Year:2012
# Now Copying Building #446/507.........UnivLab_Brenna
# ..........Year:2012
# Now Copying Building #447/507.........UnivLab_Caesar
# ..........Year:2015
# Now Copying Building #448/507.........UnivLab_Caitlin
# ..........Year:2015
# Now Copying Building #449/507.........UnivLab_Callie
# ..........Year:2015
# Now Copying Building #450/507.........UnivLab_Cam
# ..........Year:2015
# Now Copying Building #451/507.........UnivLab_Camryn
# ..........Year:2015
# Now Copying Building #452/507.........UnivLab_Carley
# ..........Year:2015
# Now Copying Building #453/507.........UnivLab_Carlos
# ..........Year:2015
# Now Copying Building #454/507.........UnivLab_Carlton
# ..........Year:2015
# Now Copying Building #455/507.........UnivLab_Carol
# ..........Year:2015
# Now Copying Building #456/507.........UnivLab_Carole
# ..........Year:2015
# Now Copying Building #457/507.........UnivLab_Cayden
# ..........Year:2015
# Now Copying Building #458/507.........UnivLab_Cecil
# ..........Year:2015
# Now Copying Building #459/507.........UnivLab_Cedric
# ..........Year:2015
# Now Copying Building #460/507.........UnivLab_Cesar
# ..........Year:2015
# Now Copying Building #461/507.........UnivLab_Cheyanne
# ..........Year:2015
# Now Copying Building #462/507.........UnivLab_Christine
# ..........Year:2015
# Now Copying Building #463/507.........UnivLab_Christy
# ..........Year:2015
# Now Copying Building #464/507.........UnivLab_Ciel
# ..........Year:2015
# Now Copying Building #465/507.........UnivLab_Cindy
# ..........Year:2015
# Now Copying Building #466/507.........UnivLab_Clint
# ..........Year:2015
# Now Copying Building #467/507.........UnivLab_Clodagh
# ..........Year:2015
# Now Copying Building #468/507.........UnivLab_Collin
# ..........Year:2015
# Now Copying Building #469/507.........UnivLab_Cory
# ..........Year:2015
# Now Copying Building #470/507.........UnivLab_Cristian
# ..........Year:2015
# Now Copying Building #471/507.........UnivLab_Crystal
# ..........Year:2015
# Now Copying Building #472/507.........UnivLab_Dianna
# ..........Year:2010
# Now Copying Building #473/507.........UnivLab_Lauren
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #474/507.........UnivLab_Lea
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #475/507.........UnivLab_Lee
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #476/507.........UnivLab_Lester
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #477/507.........UnivLab_Levi
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #478/507.........UnivLab_Lilly
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #479/507.........UnivLab_Louie
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #480/507.........UnivLab_Lyle
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #481/507.........UnivLab_Mack
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #482/507.........UnivLab_Madelyn
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #483/507.........UnivLab_Margret
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #484/507.........UnivLab_Mariana
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #485/507.........UnivLab_Marie
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #486/507.........UnivLab_Mario
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #487/507.........UnivLab_Marshall
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #488/507.........UnivLab_Miles
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #489/507.........UnivLab_Neil
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #490/507.........UnivLab_Paris
# ..........Year:2015
# Now Copying Building #491/507.........UnivLab_Parker
# ..........Year:2015
# Now Copying Building #492/507.........UnivLab_Patrick
# ..........Year:2015
# Now Copying Building #493/507.........UnivLab_Patsy
# ..........Year:2015
# Now Copying Building #494/507.........UnivLab_Paul
# ..........Year:2015
# Now Copying Building #495/507.........UnivLab_Peggy
# ..........Year:2015
# Now Copying Building #496/507.........UnivLab_Peyton
# ..........Year:2015
# Now Copying Building #497/507.........UnivLab_Phil
# ..........Year:2015
# Now Copying Building #498/507.........UnivLab_Preston
# ..........Year:2015
# Now Copying Building #499/507.........UnivLab_Priscilla
# ..........Year:2015
# Now Copying Building #500/507.........UnivLab_Santiago
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #501/507.........UnivLab_Susan
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #502/507.........UnivLab_Suzette
# ..........Year:2014
# ..........Year:2015
# Now Copying Building #503/507.........UnivLab_Tami
# ..........Year:2013
# Now Copying Building #504/507.........UnivLab_Taylor
# ..........Year:2013
# Now Copying Building #505/507.........UnivLab_Terrie
# ..........Year:2013
# Now Copying Building #506/507.........UnivLab_Tracie
# ..........Year:2013
# Now Copying Building #507/507.........UnivLab_Tracy
# ..........Year:2013

# %%
clean_and_copy('ireland')
# Out:
# Now Copying Building #1/6435.........1000
# ..........Year:2009
# ..........Year:2010
# Now Copying Building #2/6435.........1001
# ..........Year:2009
# ..........Year:2010
# Now Copying Building #3/6435.........1002
# ..........Year:2009
# ..........Year:2010
# Now Copying Building #4/6435.........1003
# ..........Year:2009
# ..........Year:2010
# Now Copying Building #5/6435.........1004
# ..........Year:2009
# ..........Year:2010
# Now Copying Building #6/6435.........1005
# ..........Year:2009
# ..........Year:2010
# Now Copying Building #7/6435.........1006
# ..........Year:2009
# ..........Year:2010
# Now Copying Building #8/6435.........1007
# ..........Year:2009
# ..........Year:2010
# Now Copying Building #9/6435.........1008
# ..........Year:2009
# ..........Year:2010
# Now Copying Building #10/6435.........1009
# ..........Year:2009
# ..........Year:2010
# Now Copying Building #11/6435.........1010
# ..........Year:2009
# ..........Year:2010
# Now Copying Building #12/6435.........1011
# ..........Year:2009
# ..........Year:2010
# Now Copying Building #13/6435.........1012
# ..........Year:2010
# Now Copying Building #14/6435.........1013
# ..........Year:2009
# ..........Year:2010
# Now Copying Building
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #27/87.........M24A
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #28/87.........M26A
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #29/87.........M26B
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #30/87.........M26C
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #31/87.........M26D
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #32/87.........M2A
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #33/87.........M32D_A
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #34/87.........M32D_B
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #35/87.........M32G_A
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #36/87.........M32G_B
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #37/87.........M33A
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #38/87.........M35A
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #39/87.........M36A
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #40/87.........M36B
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #41/87.........M36C
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #42/87.........M36D
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #43/87.........M36E
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #44/87.........M37A
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #45/87.........M37B
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #46/87.........M46A
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #47/87.........M46B
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #48/87.........M46C
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #49/87.........M46D
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #50/87.........M50A
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #51/87.........M50B
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #52/87.........M54A
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #53/87.........M54B
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #54/87.........M54C
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #55/87.........M56A
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #56/87.........M56B
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #57/87.........M66A
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #58/87.........M66B
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #59/87.........M66EMG
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #60/87.........M68A
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #61/87.........M68B
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #62/87.........M76A
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #63/87.........M76B
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #64/87.........M76C
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #65/87.........M76D
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #66/87.........M7A
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #67/87.........M9A
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #68/87.........M9B
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #69/87.........NW35A
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #70/87.........NW35B
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #71/87.........W15A
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #72/87.........W16A
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Empty dataset found
# Now Copying Building #73/87.........W1A
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #74/87.........W20A
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #75/87.........W20B
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #76/87.........W31A
# ..........Year:2015
# ..........Year:2016
# Empty dataset found
# Now Copying Building #77/87.........W34A
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #78/87.........W34B
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #79/87.........W35A
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #80/87.........W61A
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #81/87.........W70A
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #82/87.........W70B
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #83/87.........W79A
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #84/87.........W79B
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #85/87.........W85A
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #86/87.........W91A
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016
# Now Copying Building #87/87.........W91B
# ..........Year:2014
# ..........Year:2015
# ..........Year:2016

# %%
with h5py.File('iel.hdf5','r') as f:
    hours = 0 
    count = 0 
    for m in f.keys():
        dset = f[m]
        for buil in dset.keys():
            building = dset[buil]
            for y in building.keys():
                df = pd.DataFrame(building[y][()])
                hours = hours+len(df)
                count = count + 1
    print('{} Datasets and {} Total Hours'.format(count,hours))
# Out:
# 17072 Datasets and 106941395 Total Hours

# %%
with h5py.File('cleaned.hdf5','r') as f:
    hours = 0 
    count = 0 
    for m in f.keys():
        dset = f[m]
        for buil in dset.keys():
            building = dset[buil]
            for y in building.keys():
                df = pd.DataFrame(building[y][()])
                hours = hours+len(df)
                count = count + 1
    print('{} Datasets and {} Total Hours'.format(count,hours))
# Out:
# 16907 Datasets and 94118408 Total Hours

# %%
with h5py.File(file_loc,'r') as f:
    dfv = pd.DataFrame(f['pecan/7800/2017'][()])

# %%
sd = clean_zero(byte_to_obj(dfv))
sd[1] = sd.apply(lambda x: np.log(x[1]),axis=1)

# %%
sdd = gen_deriv(sd,axis=1)
np.percentile(sdd[1].tolist(),[25,75])
# Out:
# array([ 0.2934156,  0.2934156])

# %% [markdown]
# <h3><font color = #bf5700> Other Problems in Outlier Detection </font> </h3>
# Continual values

# %%
with h5py.File('iel.hdf5','r') as f:
    df = pd.DataFrame(f['MIT/W31A/2016'][()])
    sdf = clean_zero(byte_to_obj(df))
    sdf.sort_values(by=0,inplace=True)
    plot_hourly(sdf,2016, title = 'MIT W31A Energy Usage in 2016')

# %% [markdown]
# IQR of dataset is ZERO, because 25th and 75th percentile are both the same constant value ^
